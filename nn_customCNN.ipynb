# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.4.0-rc0

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [176, 208]
EPOCHS = 100

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "Alzheimer_s Dataset/train",
    validation_split=0.2, #0.2,
    subset="training",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "Alzheimer_s Dataset/train",
    validation_split=0.2, #0.2,
    subset="validation",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.

# %%
class_names = ['MildDementia', 'ModerateDementia', 'NonDementia', 'VeryMildDementia']
train_ds.class_names = class_names
val_ds.class_names = class_names

NUM_CLASSES = len(class_names)

# %% [markdown]
# NUM_CLASSES

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(train_ds.class_names[labels[i]])
    plt.axis("off")
# Out:
# 2021-08-13 04:23:30.086453: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-08-13 04:23:30.086844: W tensorflow/core/platform/profile_utils/cpu_utils.cc:126] Failed to get CPU frequency: 0 Hz

# %%
def one_hot_label(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label

# %%
train_ds = train_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)

NUM_IMAGES = []

for label in class_names:
    dir_name = "Alzheimer_s Dataset/train/" + label[:-2] + 'ed'
    NUM_IMAGES.append(len([name for name in os.listdir(dir_name)]))

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )

    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])

    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(*IMAGE_SIZE, 3)),

        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.BatchNormalization(epsilon = 1e-5, momentum=0.7),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.BatchNormalization(epsilon = 1e-5, momentum=0.7),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.BatchNormalization(epsilon = 1e-5, momentum=0.7),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        tf.keras.layers.Dropout(0.2),
        
        
        conv_block(32),
        conv_block(64),

        conv_block(128),
        tf.keras.layers.Dropout(0.2),

        conv_block(256),
        tf.keras.layers.Dropout(0.2),

        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),

        
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])

    return model

# %%
with strategy.scope():
    model = build_model()

    METRICS = [tf.keras.metrics.AUC(name='auc')]
    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)
#exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True,
                                                    verbose=1)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, lr_scheduler],
    epochs=EPOCHS
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x17a2c2ca0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x17a2c2ca0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 256/257 [============================>.] - ETA: 0s - loss: 1.3587 - auc: 0.6991WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x17ff83790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x17ff83790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 257/257 [==============================] - 18s 66ms/step - loss: 1.3573 - auc: 0.6995 - val_loss: 1.0945 - val_auc: 0.7735
# Epoch 2/100
# 257/257 [==============================] - 17s 64ms/step - loss: 1.0777 - auc: 0.7709 - val_loss: 1.0591 - val_auc: 0.7705
# Epoch 3/100
# 257/257 [==============================] - 17s 67ms/step - loss: 0.9928 - auc: 0.8031 - val_loss: 1.1603 - val_auc: 0.6398
# Epoch 4/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.9720 - auc: 0.8158 - val_loss: 1.0764 - val_auc: 0.8182
# Epoch 5/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.9393 - auc: 0.8275 - val_loss: 2.6204 - val_auc: 0.7659
# Epoch 6/100
# 257/257 [==============================] - 18s 70ms/step - loss: 0.9450 - auc: 0.8245 - val_loss: 1.1100 - val_auc: 0.8183
# Epoch 7/100
# 257/257 [==============================] - 18s 69ms/step - loss: 0.9252 - auc: 0.8308 - val_loss: 0.9678 - val_auc: 0.8305
# Epoch 8/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.9329 - auc: 0.8291 - val_loss: 0.9260 - val_auc: 0.8317
# Epoch 9/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.9172 - auc: 0.8334 - val_loss: 0.8999 - val_auc: 0.8413
# Epoch 10/100
# 257/257 [==============================] - 19s 74ms/step - loss: 0.9168 - auc: 0.8345 - val_loss: 0.8960 - val_auc: 0.8402
# Epoch 11/100
# 257/257 [==============================] - 22s 85ms/step - loss: 0.9170 - auc: 0.8372 - val_loss: 0.9781 - val_auc: 0.8323
# Epoch 12/100
# 257/257 [==============================] - 22s 85ms/step - loss: 0.9076 - auc: 0.8393 - val_loss: 1.3590 - val_auc: 0.8147
# Epoch 13/100
# 257/257 [==============================] - 23s 88ms/step - loss: 0.8985 - auc: 0.8406 - val_loss: 0.9196 - val_auc: 0.8418
# Epoch 14/100
# 257/257 [==============================] - 22s 86ms/step - loss: 0.9011 - auc: 0.8424 - val_loss: 1.0112 - val_auc: 0.8314
# Epoch 15/100
# 257/257 [==============================] - 22s 86ms/step - loss: 0.8794 - auc: 0.8495 - val_loss: 1.1183 - val_auc: 0.8270
# Epoch 16/100
# 257/257 [==============================] - 23s 89ms/step - loss: 0.8839 - auc: 0.8474 - val_loss: 0.8659 - val_auc: 0.8543
# Epoch 17/100
# 257/257 [==============================] - 17s 67ms/step - loss: 0.8901 - auc: 0.8471 - val_loss: 0.9077 - val_auc: 0.8441
# Epoch 18/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8829 - auc: 0.8531 - val_loss: 0.8748 - val_auc: 0.8506
# Epoch 19/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8951 - auc: 0.8466 - val_loss: 0.8606 - val_auc: 0.8575
# Epoch 20/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8865 - auc: 0.8470 - val_loss: 0.8728 - val_auc: 0.8523
# Epoch 21/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8807 - auc: 0.8502 - val_loss: 0.9578 - val_auc: 0.8213
# Epoch 22/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8764 - auc: 0.8525 - val_loss: 0.9529 - val_auc: 0.8285
# Epoch 23/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8799 - auc: 0.8519 - val_loss: 0.9338 - val_auc: 0.8365
# Epoch 24/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8556 - auc: 0.8594 - val_loss: 0.9374 - val_auc: 0.8328
# Epoch 25/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8650 - auc: 0.8588 - val_loss: 0.8783 - val_auc: 0.8502
# Epoch 26/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8611 - auc: 0.8580 - val_loss: 0.8661 - val_auc: 0.8598
# Epoch 27/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8634 - auc: 0.8581 - val_loss: 0.9147 - val_auc: 0.8377
# Epoch 28/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.8491 - auc: 0.8637 - val_loss: 0.8466 - val_auc: 0.8681
# Epoch 29/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8482 - auc: 0.8654 - val_loss: 0.8880 - val_auc: 0.8510
# Epoch 30/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8483 - auc: 0.8645 - val_loss: 0.8991 - val_auc: 0.8466
# Epoch 31/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8431 - auc: 0.8674 - val_loss: 0.8671 - val_auc: 0.8666
# Epoch 32/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8406 - auc: 0.8669 - val_loss: 0.8539 - val_auc: 0.8709
# Epoch 33/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8213 - auc: 0.8748 - val_loss: 0.8558 - val_auc: 0.8699
# Epoch 34/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8312 - auc: 0.8708 - val_loss: 0.8170 - val_auc: 0.8809
# Epoch 35/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8284 - auc: 0.8716 - val_loss: 0.9430 - val_auc: 0.8311
# Epoch 36/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8310 - auc: 0.8708 - val_loss: 0.8193 - val_auc: 0.8816
# Epoch 37/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8143 - auc: 0.8773 - val_loss: 0.8582 - val_auc: 0.8678
# Epoch 38/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8218 - auc: 0.8740 - val_loss: 0.9132 - val_auc: 0.8438
# Epoch 39/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8172 - auc: 0.8751 - val_loss: 1.0470 - val_auc: 0.7892
# Epoch 40/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.8336 - auc: 0.8698 - val_loss: 0.8549 - val_auc: 0.8696
# Epoch 41/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8276 - auc: 0.8735 - val_loss: 0.8609 - val_auc: 0.8678
# Epoch 42/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8111 - auc: 0.8772 - val_loss: 0.8501 - val_auc: 0.8687
# Epoch 43/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8049 - auc: 0.8806 - val_loss: 0.8720 - val_auc: 0.8607
# Epoch 44/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8245 - auc: 0.8734 - val_loss: 0.8069 - val_auc: 0.8875
# Epoch 45/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8000 - auc: 0.8813 - val_loss: 0.8131 - val_auc: 0.8843
# Epoch 46/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8203 - auc: 0.8748 - val_loss: 0.8044 - val_auc: 0.8869
# Epoch 47/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8040 - auc: 0.8812 - val_loss: 0.8085 - val_auc: 0.8852
# Epoch 48/100
# 257/257 [==============================] - 17s 67ms/step - loss: 0.8192 - auc: 0.8746 - val_loss: 0.9485 - val_auc: 0.8310
# Epoch 49/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8120 - auc: 0.8772 - val_loss: 0.8159 - val_auc: 0.8838
# Epoch 50/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8083 - auc: 0.8784 - val_loss: 0.8490 - val_auc: 0.8711
# Epoch 51/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.7940 - auc: 0.8833 - val_loss: 0.9742 - val_auc: 0.8198
# Epoch 52/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8186 - auc: 0.8748 - val_loss: 0.8649 - val_auc: 0.8660
# Epoch 53/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8169 - auc: 0.8763 - val_loss: 0.9082 - val_auc: 0.8482
# Epoch 54/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8012 - auc: 0.8813 - val_loss: 0.9515 - val_auc: 0.8299
# Epoch 55/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8201 - auc: 0.8735 - val_loss: 0.8467 - val_auc: 0.8706
# Epoch 56/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8094 - auc: 0.8784 - val_loss: 0.8576 - val_auc: 0.8685
# Epoch 57/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8138 - auc: 0.8789 - val_loss: 0.8085 - val_auc: 0.8868
# Epoch 58/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8138 - auc: 0.8761 - val_loss: 0.8171 - val_auc: 0.8831
# Epoch 59/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8126 - auc: 0.8783 - val_loss: 0.9364 - val_auc: 0.8364
# Epoch 60/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.7960 - auc: 0.8826 - val_loss: 0.8807 - val_auc: 0.8585
# Epoch 61/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8109 - auc: 0.8797 - val_loss: 0.8128 - val_auc: 0.8846
# Epoch 62/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8069 - auc: 0.8794 - val_loss: 0.8401 - val_auc: 0.8751
# Epoch 63/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8090 - auc: 0.8786 - val_loss: 0.8297 - val_auc: 0.8796
# Epoch 64/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.7989 - auc: 0.8809 - val_loss: 0.9417 - val_auc: 0.8337
# Epoch 65/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8158 - auc: 0.8756 - val_loss: 0.9094 - val_auc: 0.8470
# Epoch 66/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8078 - auc: 0.8792 - val_loss: 0.8313 - val_auc: 0.8786
# Epoch 67/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8120 - auc: 0.8786 - val_loss: 0.9084 - val_auc: 0.8480
# Epoch 68/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8020 - auc: 0.8814 - val_loss: 1.0344 - val_auc: 0.7986
# Epoch 69/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8074 - auc: 0.8789 - val_loss: 1.0212 - val_auc: 0.8016
# Epoch 70/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.8028 - auc: 0.8802 - val_loss: 0.8543 - val_auc: 0.8681
# Epoch 71/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8145 - auc: 0.8756 - val_loss: 0.9365 - val_auc: 0.8365
# Epoch 72/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.7950 - auc: 0.8826 - val_loss: 0.8552 - val_auc: 0.8689
# Epoch 73/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7848 - auc: 0.8870 - val_loss: 0.8062 - val_auc: 0.8862
# Epoch 74/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8058 - auc: 0.8808 - val_loss: 0.8538 - val_auc: 0.8695
# Epoch 75/100
# 257/257 [==============================] - 17s 67ms/step - loss: 0.7904 - auc: 0.8842 - val_loss: 0.9485 - val_auc: 0.8308
# Epoch 76/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8037 - auc: 0.8790 - val_loss: 0.8580 - val_auc: 0.8677
# Epoch 77/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8090 - auc: 0.8803 - val_loss: 0.8242 - val_auc: 0.8811
# Epoch 78/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8138 - auc: 0.8793 - val_loss: 0.8674 - val_auc: 0.8640
# Epoch 79/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7977 - auc: 0.8806 - val_loss: 0.8038 - val_auc: 0.8884
# Epoch 80/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8135 - auc: 0.8769 - val_loss: 0.8625 - val_auc: 0.8663
# Epoch 81/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.7959 - auc: 0.8851 - val_loss: 0.9641 - val_auc: 0.8252
# Epoch 82/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7910 - auc: 0.8836 - val_loss: 0.9015 - val_auc: 0.8504
# Epoch 83/100
# 257/257 [==============================] - 18s 69ms/step - loss: 0.7978 - auc: 0.8835 - val_loss: 0.9224 - val_auc: 0.8415
# Epoch 84/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.7994 - auc: 0.8836 - val_loss: 0.9837 - val_auc: 0.8172
# Epoch 85/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8039 - auc: 0.8801 - val_loss: 0.8759 - val_auc: 0.8609
# Epoch 86/100
# 257/257 [==============================] - 17s 67ms/step - loss: 0.8203 - auc: 0.8754 - val_loss: 0.8658 - val_auc: 0.8648
# Epoch 87/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7867 - auc: 0.8870 - val_loss: 0.8664 - val_auc: 0.8620
# Epoch 88/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8017 - auc: 0.8811 - val_loss: 0.8236 - val_auc: 0.8805
# Epoch 89/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8035 - auc: 0.8797 - val_loss: 0.8871 - val_auc: 0.8562
# Epoch 90/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8093 - auc: 0.8790 - val_loss: 0.8127 - val_auc: 0.8847
# Epoch 91/100
# 257/257 [==============================] - 17s 67ms/step - loss: 0.8151 - auc: 0.8775 - val_loss: 0.9208 - val_auc: 0.8425
# Epoch 92/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8006 - auc: 0.8825 - val_loss: 0.9391 - val_auc: 0.8350
# Epoch 93/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8091 - auc: 0.8777 - val_loss: 0.9047 - val_auc: 0.8490
# Epoch 94/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.7850 - auc: 0.8861 - val_loss: 0.8196 - val_auc: 0.8822
# Epoch 95/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.7973 - auc: 0.8823 - val_loss: 0.8967 - val_auc: 0.8523
# Epoch 96/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8011 - auc: 0.8816 - val_loss: 0.8817 - val_auc: 0.8588
# Epoch 97/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8046 - auc: 0.8805 - val_loss: 0.8305 - val_auc: 0.8780
# Epoch 98/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8096 - auc: 0.8765 - val_loss: 0.8618 - val_auc: 0.8663
# Epoch 99/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8203 - auc: 0.8744 - val_loss: 0.8397 - val_auc: 0.8746
# Epoch 100/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8036 - auc: 0.8803 - val_loss: 0.9151 - val_auc: 0.8450

# %%
fig, ax = plt.subplots(1, 2, figsize=(25, 5))
ax = ax.ravel()


for i, met in enumerate(['auc', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met), fontsize=20)
    ax[i].title.set_color('white')
    ax[i].set_xlabel('epochs', fontsize=20)
    ax[i].set_ylabel(met, fontsize=20)
    ax[i].legend(['train', 'val'], fontsize=20)
    ax[i].tick_params(color='w', labelcolor='w')
    ax[i].yaxis.label.set_color('white')
    ax[i].xaxis.label.set_color('white')

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "Alzheimer_s Dataset/test",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

test_ds = test_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 1279 files belonging to 4 classes.

# %%
_ = model.evaluate(test_ds)
#model.evaluate(test_ds, batch_size=64, callbacks=[tqdm_callback], verbose=0)
# Out:
# 80/80 [==============================] - 1s 15ms/step - loss: 0.8990 - auc: 0.8463
